# %%
import seaborn
import pandas as pd
import geopandas
import pysal
import numpy
import matplotlib.pyplot as plt

# %%
shp = geopandas.read_file("shp/zipcode_NYC.shp") # dtype={'GEOID10':int}
shp
# Out:
#      GEOID10                                           geometry
# 0      10001  POLYGON ((-73.98775 40.74407, -73.98819 40.743...
# 1      10002  POLYGON ((-73.99606 40.70921, -73.99608 40.709...
# 2      10003  POLYGON ((-73.98859 40.72301, -73.98864 40.722...
# 3      10004  MULTIPOLYGON (((-74.00801 40.70799, -74.00827 ...
# 4      10005  POLYGON ((-74.00766 40.70320, -74.00783 40.703...
# ..       ...                                                ...
# 173    11692  POLYGON ((-73.80319 40.58658, -73.80401 40.586...
# 174    11693  MULTIPOLYGON (((-73.81731 40.58333, -73.81770 ...
# 175    11694  POLYGON ((-73.86116 40.56751, -73.86203 40.567...
# 176    11697  POLYGON ((-73.89914 40.55680, -73.89911 40.556...
# 177    99999  MULTIPOLYGON (((-74.21417 40.55660, -74.21410 ...
#
# [178 rows x 2 columns]

# %%
ACS = pd.read_csv("attributes/ACS_2018_5year__zipcode_US_byZipcode_normalized.csv") 
ACS
# Out:
#        GEOID  Median_monthly_housing_costs  p_with_4year_college_degree  \
# 0        601                           203                          NaN
# 1        602                           175                          NaN
# 2        603                           261                          NaN
# 3        606                           129                          NaN
# 4        610                           196                          NaN
# ...      ...                           ...                          ...
# 33115  99923                         -9999                   100.000000
# 33116  99925                           515                     8.242613
# 33117  99926                           442                     6.575074
# 33118  99927                           328                    26.315789
# 33119  99929                           749                    14.026667
#
#        p_unemployed  p_manufacturing  p_below_poverty  \
# ...

# %% [markdown]
# #### Skewed
#
#
# #### non-Skewed
# p_with_4year_college_degree
# p_unemployed

# %%
selected = "p_with_4year_college_degree"      #"%_manufacturing"
mx[["GEOID10", selected]]  
# Plot histogram
ax = seaborn.histplot(mx[selected], bins=30)
# Add rug on horizontal axis
seaborn.rugplot(mx[selected], height=0.05, color="red", ax=ax);

# %%
selected = "p_unemployed"      #"%_manufacturing"
mx[["GEOID10", selected]]  
# Plot histogram
ax = seaborn.histplot(mx[selected], bins=30)
# Add rug on horizontal axis
seaborn.rugplot(mx[selected], height=0.05, color="red", ax=ax);

# %%
selected = "p_manufacturing"      #"%_manufacturing"
mx[["GEOID10", selected]]  
# Plot histogram
ax = seaborn.histplot(mx[selected], bins=30)
# Add rug on horizontal axis
seaborn.rugplot(mx[selected], height=0.05, color="red", ax=ax);

# %%
selected = "p_below_poverty"      #"%_manufacturing"
mx[["GEOID10", selected]]  
# Plot histogram
ax = seaborn.histplot(mx[selected], bins=30)
# Add rug on horizontal axis
seaborn.rugplot(mx[selected], height=0.05, color="red", ax=ax);

# %%
selected = "p_structures_more_than_30_years_old"      #"%_manufacturing"
mx[["GEOID10", selected]]  
# Plot histogram
ax = seaborn.histplot(mx[selected], bins=30)
# Add rug on horizontal axis
seaborn.rugplot(mx[selected], height=0.05, color="red", ax=ax);

# %%
selected = "p_households_moved_<10_years_ago"      #"%_manufacturing"
mx[["GEOID10", selected]]  
# Plot histogram
ax = seaborn.histplot(mx[selected], bins=30)
# Add rug on horizontal axis
seaborn.rugplot(mx[selected], height=0.05, color="red", ax=ax);

# %%
selected = "p_>_60_years_old"      #"%_manufacturing"
mx[["GEOID10", selected]]  
# Plot histogram
ax = seaborn.histplot(mx[selected], bins=30)
# Add rug on horizontal axis
seaborn.rugplot(mx[selected], height=0.05, color="red", ax=ax);

# %%
selected = "p_service_industry"      #"%_manufacturing"
mx[["GEOID10", selected]]  
# Plot histogram
ax = seaborn.histplot(mx[selected], bins=30)
# Add rug on horizontal axis
seaborn.rugplot(mx[selected], height=0.05, color="red", ax=ax);

# %%
selected = "p_vacant_housing"      #"%_manufacturing"
mx[["GEOID10", selected]]  
# Plot histogram
ax = seaborn.histplot(mx[selected], bins=30)
# Add rug on horizontal axis
seaborn.rugplot(mx[selected], height=0.05, color="red", ax=ax);

# %%
selected = "p_owner_occupied_housing"      #"%_manufacturing"
mx[["GEOID10", selected]]  
# Plot histogram
ax = seaborn.histplot(mx[selected], bins=30)
# Add rug on horizontal axis
seaborn.rugplot(mx[selected], height=0.05, color="red", ax=ax);

# %%
selected = "p_multiunit_structures"      #"%_manufacturing"
mx[["GEOID10", selected]]  
# Plot histogram
ax = seaborn.histplot(mx[selected], bins=30)
# Add rug on horizontal axis
seaborn.rugplot(mx[selected], height=0.05, color="red", ax=ax);

# %%
selected = "p_<_18_years_old"      #"%_manufacturing"
mx[["GEOID10", selected]]  
# Plot histogram
ax = seaborn.histplot(mx[selected], bins=30)
# Add rug on horizontal axis
seaborn.rugplot(mx[selected], height=0.05, color="red", ax=ax);

# %%
selected = "p_black"      #"%_manufacturing"
mx[["GEOID10", selected]]  
# Plot histogram
ax = seaborn.histplot(mx[selected], bins=30)
# Add rug on horizontal axis
seaborn.rugplot(mx[selected], height=0.05, color="red", ax=ax);

# %%
selected = "p_white"      #"%_manufacturing"
mx[["GEOID10", selected]]  
# Plot histogram
ax = seaborn.histplot(mx[selected], bins=30)
# Add rug on horizontal axis
seaborn.rugplot(mx[selected], height=0.05, color="red", ax=ax);

# %%
selected = "p_Hispanic"      #"%_manufacturing"
mx[["GEOID10", selected]]  
# Plot histogram
ax = seaborn.histplot(mx[selected], bins=30)
# Add rug on horizontal axis
seaborn.rugplot(mx[selected], height=0.05, color="red", ax=ax);

# %%
selected = "p_Asian"      #"%_manufacturing"
mx[["GEOID10", selected]]  
# Plot histogram
ax = seaborn.histplot(mx[selected], bins=30)
# Add rug on horizontal axis
seaborn.rugplot(mx[selected], height=0.05, color="red", ax=ax);

# %%
selected = "p_foreign_born"      #"%_manufacturing"
mx[["GEOID10", selected]]  
# Plot histogram
ax = seaborn.histplot(mx[selected], bins=30)
# Add rug on horizontal axis
seaborn.rugplot(mx[selected], height=0.05, color="red", ax=ax);

# %%
selected = "p_health_insurance"      #"%_manufacturing"
mx[["GEOID10", selected]]  
# Plot histogram
ax = seaborn.histplot(mx[selected], bins=30)
# Add rug on horizontal axis
seaborn.rugplot(mx[selected], height=0.05, color="red", ax=ax);

# %%
selected = "p_without_health_insurance"      #"%_manufacturing"
mx[["GEOID10", selected]]  
# Plot histogram
ax = seaborn.histplot(mx[selected], bins=30)
# Add rug on horizontal axis
seaborn.rugplot(mx[selected], height=0.05, color="red", ax=ax);

# %%
selected = "Median_Age"      #"%_manufacturing"
mx[["GEOID10", selected]]  
# Plot histogram
ax = seaborn.histplot(mx[selected], bins=30)
# Add rug on horizontal axis
seaborn.rugplot(mx[selected], height=0.05, color="red", ax=ax);

# %%
selected = "p_Native_Hawaiian_and_other_Pacific_Islander_alone"      #"%_manufacturing"
mx[["GEOID10", selected]]  
# Plot histogram
ax = seaborn.histplot(mx[selected], bins=30)
# Add rug on horizontal axis
seaborn.rugplot(mx[selected], height=0.05, color="red", ax=ax);

# %%
selected = "p_American_Indian_and_Alaska_Native_alone"      #"%_manufacturing"
mx[["GEOID10", selected]]  
# Plot histogram
ax = seaborn.histplot(mx[selected], bins=30)
# Add rug on horizontal axis
seaborn.rugplot(mx[selected], height=0.05, color="red", ax=ax);

# %%
selected = "p_public_transportation"      #"%_manufacturing"
mx[["GEOID10", selected]]  
# Plot histogram
ax = seaborn.histplot(mx[selected], bins=30)
# Add rug on horizontal axis
seaborn.rugplot(mx[selected], height=0.05, color="red", ax=ax);

# %%
selected = "p_walked"      #"%_manufacturing"
mx[["GEOID10", selected]]  
# Plot histogram
ax = seaborn.histplot(mx[selected], bins=30)
# Add rug on horizontal axis
seaborn.rugplot(mx[selected], height=0.05, color="red", ax=ax);

# %%
selected = "Median_gross_rent"      #"%_manufacturing"
mx[["GEOID10", selected]]  
# Plot histogram
ax = seaborn.histplot(mx[selected], bins=30)
# Add rug on horizontal axis
seaborn.rugplot(mx[selected], height=0.05, color="red", ax=ax);

# %%
selected = "p_management,_business,_science,_and_arts_occupations"      #"%_manufacturing"
mx[["GEOID10", selected]]  
# Plot histogram
ax = seaborn.histplot(mx[selected], bins=30)
# Add rug on horizontal axis
seaborn.rugplot(mx[selected], height=0.05, color="red", ax=ax);

# %%
selected = "p_natural_resources,_construction,_and_maintenance_occupation"      #"%_manufacturing"
mx[["GEOID10", selected]]  
# Plot histogram
ax = seaborn.histplot(mx[selected], bins=30)
# Add rug on horizontal axis
seaborn.rugplot(mx[selected], height=0.05, color="red", ax=ax);

# %%
selected = "p_production,_transportation,_and_material_moving_occupations"      #"%_manufacturing"
mx[["GEOID10", selected]]  
# Plot histogram
ax = seaborn.histplot(mx[selected], bins=30)
# Add rug on horizontal axis
seaborn.rugplot(mx[selected], height=0.05, color="red", ax=ax);

# %%
selected = "p_information"      #"%_manufacturing"
mx[["GEOID10", selected]]  
# Plot histogram
ax = seaborn.histplot(mx[selected], bins=30)
# Add rug on horizontal axis
seaborn.rugplot(mx[selected], height=0.05, color="red", ax=ax);

# %%
selected = "p_professional,_scientific,_and_management,_and_administrative_and_waste_management_services"      #"%_manufacturing"
mx[["GEOID10", selected]]  
# Plot histogram
ax = seaborn.histplot(mx[selected], bins=30)
# Add rug on horizontal axis
seaborn.rugplot(mx[selected], height=0.05, color="red", ax=ax);

# %%
selected = "p_arts,_entertainment,_and_recreation,_and_accommodation_and_food_services"      #"%_manufacturing"
mx[["GEOID10", selected]]  
# Plot histogram
ax = seaborn.histplot(mx[selected], bins=30)
# Add rug on horizontal axis
seaborn.rugplot(mx[selected], height=0.05, color="red", ax=ax);

# %%
selected = "p_renter_occupied"      #"%_manufacturing"
mx[["GEOID10", selected]]  
# Plot histogram
ax = seaborn.histplot(mx[selected], bins=30)
# Add rug on horizontal axis
seaborn.rugplot(mx[selected], height=0.05, color="red", ax=ax);
