# %%
import seaborn
import pandas as pd
import geopandas
import pysal
import numpy
import matplotlib.pyplot as plt

# %%
shp = geopandas.read_file("shp/zipcode_NYC.shp") # dtype={'GEOID10':int}
shp
# Out:
#      GEOID10                                           geometry
# 0      10001  POLYGON ((-73.98775 40.74407, -73.98819 40.743...
# 1      10002  POLYGON ((-73.99606 40.70921, -73.99608 40.709...
# 2      10003  POLYGON ((-73.98859 40.72301, -73.98864 40.722...
# 3      10004  MULTIPOLYGON (((-74.00801 40.70799, -74.00827 ...
# 4      10005  POLYGON ((-74.00766 40.70320, -74.00783 40.703...
# ..       ...                                                ...
# 173    11692  POLYGON ((-73.80319 40.58658, -73.80401 40.586...
# 174    11693  MULTIPOLYGON (((-73.81731 40.58333, -73.81770 ...
# 175    11694  POLYGON ((-73.86116 40.56751, -73.86203 40.567...
# 176    11697  POLYGON ((-73.89914 40.55680, -73.89911 40.556...
# 177    99999  MULTIPOLYGON (((-74.21417 40.55660, -74.21410 ...
#
# [178 rows x 2 columns]

# %%
ACS = pd.read_csv("attributes/ACS_2018_5year__zipcode_US_byZipcode_normalized.csv") 
ACS
# Out:
#        GEOID  Median_monthly_housing_costs  p_with_4year_college_degree  \
# 0        601                           203                          NaN
# 1        602                           175                          NaN
# 2        603                           261                          NaN
# 3        606                           129                          NaN
# 4        610                           196                          NaN
# ...      ...                           ...                          ...
# 33115  99923                         -9999                   100.000000
# 33116  99925                           515                     8.242613
# 33117  99926                           442                     6.575074
# 33118  99927                           328                    26.315789
# 33119  99929                           749                    14.026667
#
#        p_unemployed  p_manufacturing  p_below_poverty  \
# 0         21.732314         7.674486              NaN
# 1          7.814260         8.991611              NaN
# 2         10.998628        11.756802              NaN
# 3          5.614837        16.014760              NaN
# 4          7.466749        20.319390              NaN
# ...             ...              ...              ...
# 33115      0.000000         0.000000         0.000000
# 33116     12.606474         2.564103        18.574514
# 33117     14.362272         7.265774        14.443762
# 33118      0.000000         0.000000        73.684211
# 33119      4.357143         3.886256         7.795371
#
#        p_structures_more_than_30_years_old  p_households_moved_<10_years_ago  \
# 0                                46.348941                         25.546170
# 1                                53.990691                         16.453320
# 2                                52.190367                         31.781678
# 3                                52.004334                         21.707963
# 4                                52.632003                         18.158881
# ...                                    ...                               ...
# 33115                            42.592593                          0.000000
# 33116                            38.516746                         39.697950
# 33117                            55.291971                         30.920245
# 33118                            33.333333                          0.000000
# 33119                            59.034483                         37.474290
#
#        p_>_60_years_old  p_service_industry  ...  \
# 0             24.364923           23.110339  ...
# 1             24.769783           26.459280  ...
# 2             26.160528           21.531743  ...
# 3             25.710735           24.797048  ...
# 4             25.427548           23.942319  ...
# ...                 ...                 ...  ...
# 33115        100.000000            0.000000  ...
# 33116         18.338727           13.675214  ...
# 33117         18.837920           18.546845  ...
# 33118         26.315789            0.000000  ...
# 33119         30.555556           17.251185  ...
#
#        p_housing_units_1-unit,_detached  p_housing_units_1-unit,_attached  \
# 0                             81.814381                         10.437570
# 1                             70.085617                          2.499569
# 2                             66.352680                         15.433343
# 3                             87.323944                          9.823041
# 4                             73.639661                          4.820637
# ...                                 ...                               ...
# 33115                         85.185185                          0.000000
# 33116                         59.569378                          0.478469
# 33117                         72.080292                          4.927007
# 33118                        100.000000                          0.000000
# 33119                         66.206897                          0.413793
#
#        p_housing_units_2_units  p_housing_units_3_or_4_units  \
# 0                     0.933668                      2.146042
# 1                    21.634201                      3.861403
# 2                     2.278804                      1.978528
# 3                     0.216685                      0.469484
# 4                    15.002015                      2.466747
# ...                        ...                           ...
# 33115                 0.000000                      0.000000
# 33116                 5.502392                      0.956938
# 33117                 1.824818                      2.189781
# 33118                 0.000000                      0.000000
# 33119                 3.448276                      5.517241
#
#        p_housing_units_5_to_9_units  p_housing_units_10_to_19_units  \
# 0                          2.424749                        1.546823
# 1                          1.195196                        0.103430
# 2                          3.586854                        6.618403
# 3                          1.227880                        0.650054
# 4                          2.120113                        0.951229
# ...                             ...                             ...
# 33115                      0.000000                        0.000000
# 33116                      1.674641                        2.870813
# 33117                      2.554745                        1.642336
# 33118                      0.000000                        0.000000
# 33119                      7.172414                        0.413793
#
#        p_housing_units_20_or_more_units  p_housing_units_mobile_home  \
# 0                              0.459866                     0.236901
# 1                              0.620583                     0.000000
# 2                              3.665008                     0.086381
# 3                              0.000000                     0.288913
# 4                              0.854494                     0.145103
# ...                                 ...                          ...
# 33115                          0.000000                    14.814815
# 33116                          3.110048                    23.684211
# 33117                          1.277372                    13.503650
# 33118                          0.000000                     0.000000
# 33119                          1.793103                    15.034483
#
#        p_housing_units_boat,_rv,_van,_etc  p_housing_units_two_or_more
# 0                                 0.00000                     5.086399
# 1                                 0.00000                    26.219617
# 2                                 0.00000                    14.540743
# 3                                 0.00000                     1.336222
# 4                                 0.00000                    19.274486
# ...                                   ...                          ...
# 33115                             0.00000                     0.000000
# 33116                             2.15311                    12.440191
# 33117                             0.00000                     6.934307
# 33118                             0.00000                     0.000000
# 33119                             0.00000                    11.172414
#
# [33120 rows x 224 columns]

# %%
mx = pd.merge(shp, ACS, left_on="GEOID10", right_on="GEOID")
mx.head()
# Out:
#    GEOID10                                           geometry  GEOID  \
# 0    10001  POLYGON ((-73.98775 40.74407, -73.98819 40.743...  10001
# 1    10002  POLYGON ((-73.99606 40.70921, -73.99608 40.709...  10002
# 2    10003  POLYGON ((-73.98859 40.72301, -73.98864 40.722...  10003
# 3    10004  MULTIPOLYGON (((-74.00801 40.70799, -74.00827 ...  10004
# 4    10005  POLYGON ((-74.00766 40.70320, -74.00783 40.703...  10005
#
#    Median_monthly_housing_costs  p_with_4year_college_degree  p_unemployed  \
# 0                          1817                    37.864887      3.514080
# 1                           980                    21.852603      4.919751
# 2                          2190                    42.439063      4.026729
# 3                          3236                    47.506871      3.201970
# 4                          3238                    48.451260      2.877036
#
#    p_manufacturing  p_below_poverty  p_structures_more_than_30_years_old  \
# 0         2.138100        13.263494                            60.688777
# 1         3.746494        27.657486                            88.299183
# 2         2.383478         8.453640                            90.238373
# 3         2.372881         2.179657                            68.162693
# 4         1.717187         9.511947                            74.001791
#
#    p_households_moved_<10_years_ago  ...  p_housing_units_1-unit,_detached  \
# 0                         56.768879  ...                          1.308253
# 1                         34.454826  ...                          0.621431
# 2                         53.661991  ...                          1.586993
# 3                         65.211640  ...                          1.028518
# 4                         89.936465  ...                          0.393912
#
#    p_housing_units_1-unit,_attached  p_housing_units_2_units  \
# 0                          0.304080                 1.584046
# 1                          0.257530                 1.027321
# 2                          0.667185                 1.551367
# 3                          0.000000                 0.000000
# 4                          0.000000                 0.053715
#
#    p_housing_units_3_or_4_units  p_housing_units_5_to_9_units  \
# 0                      0.735450                      2.885227
# 1                      1.861494                      5.732841
# 2                      2.804767                      7.264542
# 3                      2.057036                      1.122020
# 4                      0.000000                      0.143241
#
#    p_housing_units_10_to_19_units  p_housing_units_20_or_more_units  \
# 0                        7.743441                         85.439502
# 1                       14.947934                         75.498264
# 2                       14.626247                         71.498899
# 3                        1.589528                         94.202899
# 4                        0.680394                         98.728738
#
#    p_housing_units_mobile_home  p_housing_units_boat,_rv,_van,_etc  \
# 0                     0.000000                            0.000000
# 1                     0.022394                            0.030792
# 2                     0.000000                            0.000000
# 3                     0.000000                            0.000000
# 4                     0.000000                            0.000000
#
#    p_housing_units_two_or_more
# 0                    95.502440
# 1                    93.335013
# 2                    90.481280
# 3                    97.849462
# 4                    99.462847
#
# [5 rows x 226 columns]

# %%
selected = "p_manufacturing"      #"%_manufacturing"
mx[["GEOID10", selected]]  
# Plot histogram
ax = seaborn.histplot(mx[selected], bins=30)
# Add rug on horizontal axis
seaborn.rugplot(mx[selected], height=0.05, color="red", ax=ax);

# %%
mx[selected].describe()
# Out:
# count    177.000000
# mean       3.173999
# std        1.201548
# min        0.000000
# 25%        2.372881
# 50%        3.015010
# 75%        3.918793
# max        7.208543
# Name: p_manufacturing, dtype: float64

# %%
import mapclassify

# %%
ei5 = mapclassify.EqualInterval(mx[selected], k=5)
ei5
# Out:
# EqualInterval
#
#   Interval     Count
# --------------------
# [0.00, 1.44] |     7
# (1.44, 2.88] |    73
# (2.88, 4.33] |    65
# (4.33, 5.77] |    27
# (5.77, 7.21] |     5

# %%
ax = mx.plot(
    figsize=(10,10),
    column=selected,  # Data to plot
    scheme="EqualInterval",  # Classification scheme
    cmap="YlGn",  # Color palette
    legend=True,  # Add legend
)
ax.set_axis_off();

# %%
q5 = mapclassify.Quantiles(mx[selected], k=5)
q5
# Out:
# Quantiles
#
#   Interval     Count
# --------------------
# [0.00, 2.27] |    36
# (2.27, 2.77] |    35
# (2.77, 3.20] |    35
# (3.20, 4.25] |    35
# (4.25, 7.21] |    36

# %%
ax = mx.plot(
    figsize=(10,10),
    column=selected,  # Data to plot
    scheme="Quantiles",  # Classification scheme
    cmap="YlGn",  # Color palette
    legend=True,  # Add legend
)
ax.set_axis_off();

# %%
msd = mapclassify.StdMean(mx[selected])
msd
# Out:
# StdMean
#
#   Interval     Count
# --------------------
# [0.00, 0.77] |     4
# (0.77, 1.97] |    19
# (1.97, 4.38] |   123
# (4.38, 5.58] |    25
# (5.58, 7.21] |     6

# %%
ax = mx.plot(
    figsize=(10,10),    
    column=selected,  # Data to plot
    scheme="StdMean",  # Classification scheme
    cmap="YlGn",  # Color palette
    legend=True,  # Add legend
)
ax.set_axis_off();

# %%
mb5 = mapclassify.MaximumBreaks(mx[selected], k=5)
mb5
# Out:
# MaximumBreaks
#
#   Interval     Count
# --------------------
# [0.00, 0.33] |     1
# (0.33, 0.92] |     3
# (0.92, 6.30] |   170
# (6.30, 6.90] |     1
# (6.90, 7.21] |     2

# %%
ax = mx.plot(
    figsize=(10,10),    
    column=selected,  # Data to plot
    scheme="MaximumBreaks",  # Classification scheme
    cmap="YlGn",  # Color palette
    legend=True,  # Add legend
)
ax.set_axis_off();

# %%
ht = mapclassify.HeadTailBreaks(mx[selected])
ht
# Out:
# HeadTailBreaks
#
#   Interval     Count
# --------------------
# [0.00, 3.17] |   104
# (3.17, 4.30] |    39
# (4.30, 5.02] |    23
# (5.02, 5.85] |     7
# (5.85, 6.75] |     2
# (6.75, 7.20] |     1
# (7.20, 7.21] |     1

# %%
ax = mx.plot(
    figsize=(10,10),
    column=selected,  # Data to plot
    scheme="HeadTailBreaks",  # Classification scheme
    cmap="YlGn",  # Color palette
    legend=True,  # Add legend
)
ax.set_axis_off();

# %%
numpy.random.seed(12345)
jc5 = mapclassify.JenksCaspall(mx[selected], k=5)
jc5
# Out:
# JenksCaspall
#
#   Interval     Count
# --------------------
# [0.00, 1.94] |    23
# (1.94, 2.70] |    44
# (2.70, 3.38] |    47
# (3.38, 4.16] |    26
# (4.16, 7.21] |    37

# %%
ax = mx.plot(
    figsize=(10,10),
    column=selected,  # Data to plot
    scheme="JenksCaspall",  # Classification scheme
    cmap="YlGn",  # Color palette
    legend=True,  # Add legend
)
ax.set_axis_off();

# %%
numpy.random.seed(12345)
fj5 = mapclassify.FisherJenks(mx[selected], k=5)
fj5
# Out:
# FisherJenks
#
#   Interval     Count
# --------------------
# [0.00, 1.94] |    23
# (1.94, 2.88] |    58
# (2.88, 3.92] |    52
# (3.92, 5.16] |    37
# (5.16, 7.21] |     7

# %%
ax = mx.plot(
    figsize=(10,10),
    column=selected,  # Data to plot
    scheme="FisherJenks",  # Classification scheme
    cmap="YlGn",  # Color palette
    legend=True,  # Add legend
)
ax.set_axis_off();

# %%
mp5 = mapclassify.MaxP(mx[selected], k=5)
mp5
# Out:
# MaxP
#
#   Interval     Count
# --------------------
# [0.00, 2.75] |    70
# (2.75, 3.18] |    36
# (3.18, 3.25] |     2
# (3.25, 5.99] |    66
# (5.99, 7.21] |     3

# %%
ax = mx.plot(
    figsize=(10,10),
    column=selected,  # Data to plot
    scheme="MaxP",  # Classification scheme
    cmap="YlGn",  # Color palette
    legend=True,  # Add legend
)
ax.set_axis_off();

# %%
### EqualInterval, Quantiles, StdMean, MaximumBreaks, HeadTailBreaks, JenksCaspall, FisherJenks, MaxP

# %%
# Bunch classifier objects
class5 = ei5, q5, msd, mb5, ht, jc5, fj5, mp5
# Collect ADCM for each classifier
fits = numpy.array([c.adcm for c in class5])
# Convert ADCM scores to a DataFrame
adcms = pd.DataFrame(fits)
# Add classifier names
adcms["classifier"] = [c.name for c in class5]
# Add column names to the ADCM
adcms.columns = ["ADCM", "Classifier"]
ax = seaborn.barplot(
    y="Classifier", x="ADCM", data=adcms, palette="Pastel1"
)
